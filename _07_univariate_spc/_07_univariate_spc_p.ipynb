# %% [markdown]
# ```
# [Title] SPC - P chart
# [Author] Yibeck Lee(yibec.Lee@gmail.com)
# [Contents]
#  - P chart for FDC Parameters
# ```

# %%
import pandas as pd
from pyspc import *
import numpy as np
df = pd.read_csv("CIRCUIT.csv")
P = spc(df.values) + p() + rules()
print(P)
# Out:
# <pyspc: (13934449)>
