# %% [markdown]
# ```
# [Title] SPC - EWMA chart
# [Author] Yibeck Lee(yibec.Lee@gmail.com)
# [Contents]
#  - EWMA(Exponentially Weighted Moving Avegare) chart for FDC Parameters
# ```

# %%
import pandas as pd

df = pd.read_csv("pistonring.csv")
df
# Out:
#         V1      V2      V3      V4      V5
# 0   74.030  74.002  74.019  73.992  74.008
# 1   73.995  73.992  74.001  74.011  74.004
# 2   73.988  74.024  74.021  74.005  74.002
# 3   74.002  73.996  73.993  74.015  74.009
# 4   73.992  74.007  74.015  73.989  74.014
# 5   74.009  73.994  73.997  73.985  73.993
# 6   73.995  74.006  73.994  74.000  74.005
# 7   73.985  74.003  73.993  74.015  73.988
# 8   74.008  73.995  74.009  74.005  74.004
# 9   73.998  74.000  73.990  74.007  73.995
# 10  73.994  73.998  73.994  73.995  73.990
# 11  74.004  74.000  74.007  74.000  73.996
# 12  73.983  74.002  73.998  73.997  74.012
# 13  74.006  73.967  73.994  74.000  73.984
# 14  74.012  74.014  73.998  73.999  74.007
# 15  74.000  73.984  74.005  73.998  73.996
# 16  73.994  74.012  73.986  74.005  74.007
# 17  74.006  74.010  74.018  74.003  74.000
# 18  73.984  74.002  74.003  74.005  73.997
# 19  74.000  74.010  74.013  74.020  74.003
# 20  73.988  74.001  74.009  74.005  73.996
# ...

# %%
from pyspc import *
EWMA = spc(df.values) + ewma()
print(EWMA)
# Out:
# <pyspc: (11742321)>
